# %% [markdown]
# <a href="https://colab.research.google.com/github/StephanieRomao/DataTwitter-Eleitoral/blob/main/Etapa_2_Coleta_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Apresentação do projeto
# #####Proposta para a construção de uma aplicação que realiza análise de sentimentos dos candidatos à presidência.

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snscrape in /usr/local/lib/python3.7/dist-packages (0.3.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.2.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)

# %% [markdown]
# #Importando as bibliotecas

# %%
import snscrape.modules.twitter as sntwitter

#Manipulação de dados
import pandas as pd

# %%
maximo_de_tweets = 10

# %% [markdown]
# #Lula

# %%
lista_de_twitts_lula = []

# %%
type (lista_de_twitts_lula)
# Out:
# list

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper ( ['lula'] ).get_items ()):
  if i > maximo_de_tweets:
    break
  lista_de_twitts_lula.append ([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_lula = pd.DataFrame(lista_de_twitts_lula, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:55:05+00:00  1553393749631303681
# 1 2022-07-30 14:55:04+00:00  1553393747936923649
# 2 2022-07-30 14:55:04+00:00  1553393746657656833
# 3 2022-07-30 14:55:04+00:00  1553393746334588928
# 4 2022-07-30 14:55:04+00:00  1553393745655103490
#
#                                                Tweet
# 0  @vidaloukanomar @liziara @YaiaSobreira @alvaro...
# 1  Quem for votar no Lula, me segue que eu sigo d...
# 2  @FABIOAGUAYO @SF_Moro @rosangelamorosp E vão p...
# 3               @LulaOficial Bom dia presidente Lula
# 4  @abdalafarah @LulaOficial Eu já tenho mais de ...

# %%
dataframe_tweets_lula['Cadidato'] = 'Lula'

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:55:05+00:00  1553393749631303681
# 1 2022-07-30 14:55:04+00:00  1553393747936923649
# 2 2022-07-30 14:55:04+00:00  1553393746657656833
# 3 2022-07-30 14:55:04+00:00  1553393746334588928
# 4 2022-07-30 14:55:04+00:00  1553393745655103490
#
#                                                Tweet Cadidato
# 0  @vidaloukanomar @liziara @YaiaSobreira @alvaro...     Lula
# 1  Quem for votar no Lula, me segue que eu sigo d...     Lula
# 2  @FABIOAGUAYO @SF_Moro @rosangelamorosp E vão p...     Lula
# 3               @LulaOficial Bom dia presidente Lula     Lula
# 4  @abdalafarah @LulaOficial Eu já tenho mais de ...     Lula

# %% [markdown]
# #Jair Bolsonaro

# %%
lista_de_twitts_jair_bolsonaro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper ( ['jair bolsonaro'] ).get_items ()):
  if i > maximo_de_tweets:
    break
  lista_de_twitts_jair_bolsonaro.append ([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_jair_bolsonaro = pd.DataFrame(lista_de_twitts_jair_bolsonaro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_jair_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:54:07+00:00  1553393506504392706
# 1 2022-07-30 14:54:06+00:00  1553393504319160320
# 2 2022-07-30 14:54:06+00:00  1553393503543169024
# 3 2022-07-30 14:54:01+00:00  1553393481577631745
# 4 2022-07-30 14:54:00+00:00  1553393476934373377
#
#                                                Tweet
# 0      @CarlaZambelli38 @jairbolsonaro Bom dia Carla
# 1  @jairbolsonaro grande feito https://t.co/7WpPH...
# 2                      @jairbolsonaro Avante Brasil!
# 3  @LulaOficial Esse aí que escreve os twitter do...
# 4  @cris_tivolitom @Gliceriaroratt2 Gasolina subi...

# %%
dataframe_tweets_jair_bolsonaro['Cadidato'] = 'Bolsonaro'

# %%
dataframe_tweets_jair_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:54:07+00:00  1553393506504392706
# 1 2022-07-30 14:54:06+00:00  1553393504319160320
# 2 2022-07-30 14:54:06+00:00  1553393503543169024
# 3 2022-07-30 14:54:01+00:00  1553393481577631745
# 4 2022-07-30 14:54:00+00:00  1553393476934373377
#
#                                                Tweet   Cadidato
# 0      @CarlaZambelli38 @jairbolsonaro Bom dia Carla  Bolsonaro
# 1  @jairbolsonaro grande feito https://t.co/7WpPH...  Bolsonaro
# 2                      @jairbolsonaro Avante Brasil!  Bolsonaro
# 3  @LulaOficial Esse aí que escreve os twitter do...  Bolsonaro
# 4  @cris_tivolitom @Gliceriaroratt2 Gasolina subi...  Bolsonaro

# %% [markdown]
# #Ciro Gomes

# %%
lista_de_twitts_ciro_gomes = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper ( ['ciro gomes'] ).get_items ()):
  if i > maximo_de_tweets:
    break
  lista_de_twitts_ciro_gomes.append ([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_ciro_gomes = pd.DataFrame(lista_de_twitts_ciro_gomes, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_ciro_gomes.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:56:14+00:00  1553394039575220231
# 1 2022-07-30 14:56:06+00:00  1553394005332877313
# 2 2022-07-30 14:56:06+00:00  1553394004628226048
# 3 2022-07-30 14:56:01+00:00  1553393985921716226
# 4 2022-07-30 14:55:57+00:00  1553393968678948864
#
#                                                Tweet
# 0  Isolado, Ciro elogia Lula e sinaliza que esta ...
# 1  @o_antagonista @cirogomes É UMA PENA \nO BRASI...
# 2  @ofilhodopastor @AndreJanonesAdv @cirogomes Ma...
# 3  @Lueira2 @UOLNoticias @cirogomes Mas ele não q...
# 4  @AndreJanonesAdv @cirogomes É assim que funcio...

# %%
dataframe_tweets_ciro_gomes['Cadidato'] = 'Ciro'

# %%
dataframe_tweets_ciro_gomes.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:56:14+00:00  1553394039575220231
# 1 2022-07-30 14:56:06+00:00  1553394005332877313
# 2 2022-07-30 14:56:06+00:00  1553394004628226048
# 3 2022-07-30 14:56:01+00:00  1553393985921716226
# 4 2022-07-30 14:55:57+00:00  1553393968678948864
#
#                                                Tweet Cadidato
# 0  Isolado, Ciro elogia Lula e sinaliza que esta ...     Ciro
# 1  @o_antagonista @cirogomes É UMA PENA \nO BRASI...     Ciro
# 2  @ofilhodopastor @AndreJanonesAdv @cirogomes Ma...     Ciro
# 3  @Lueira2 @UOLNoticias @cirogomes Mas ele não q...     Ciro
# 4  @AndreJanonesAdv @cirogomes É assim que funcio...     Ciro

# %% [markdown]
# #Simone Tebet

# %%
lista_de_twitts_simone_tebet = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper ( ['simone tebet'] ).get_items ()):
  if i > maximo_de_tweets:
    break
  lista_de_twitts_simone_tebet.append ([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_simone_tebet = pd.DataFrame(lista_de_twitts_simone_tebet, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_simone_tebet.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:51:10+00:00  1553392764175400961
# 1 2022-07-30 14:50:04+00:00  1553392489700233219
# 2 2022-07-30 14:49:29+00:00  1553392340273975298
# 3 2022-07-30 14:48:37+00:00  1553392122954391553
# 4 2022-07-30 14:47:20+00:00  1553391800634654720
#
#                                                Tweet
# 0  @simonetebetbr BOM DIA TABLET, MEUS VIZINHOS Q...
# 1  @simonetebetbr no PÂNICO 😱 entrou em PÂNICO 😱 ...
# 2  No Pânico, Simone Tebet ataca Bolsonaro e diz ...
# 3  @meupaiseursal @cirogomes @simonetebetbr Conco...
# 4  @GraziMFrauches @simonetebetbr Já tive uma cer...

# %%
dataframe_tweets_simone_tebet['Cadidato'] = 'Simone'

# %%
dataframe_tweets_simone_tebet.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:51:10+00:00  1553392764175400961
# 1 2022-07-30 14:50:04+00:00  1553392489700233219
# 2 2022-07-30 14:49:29+00:00  1553392340273975298
# 3 2022-07-30 14:48:37+00:00  1553392122954391553
# 4 2022-07-30 14:47:20+00:00  1553391800634654720
#
#                                                Tweet Cadidato
# 0  @simonetebetbr BOM DIA TABLET, MEUS VIZINHOS Q...   Simone
# 1  @simonetebetbr no PÂNICO 😱 entrou em PÂNICO 😱 ...   Simone
# 2  No Pânico, Simone Tebet ataca Bolsonaro e diz ...   Simone
# 3  @meupaiseursal @cirogomes @simonetebetbr Conco...   Simone
# 4  @GraziMFrauches @simonetebetbr Já tive uma cer...   Simone

# %% [markdown]
# #André Janones

# %%
lista_de_twitts_andre_janones = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper ( ['andré janones'] ).get_items ()):
  if i > maximo_de_tweets:
    break
  lista_de_twitts_andre_janones.append ([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_andre_janones = pd.DataFrame(lista_de_twitts_andre_janones, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_andre_janones.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:58:17+00:00  1553394554245611521
# 1 2022-07-30 14:52:18+00:00  1553393051447476225
# 2 2022-07-30 14:51:22+00:00  1553392814909784064
# 3 2022-07-30 14:49:22+00:00  1553392312616632321
# 4 2022-07-30 14:48:01+00:00  1553391972160782337
#
#                                                Tweet
# 0  "Lula está fazendo um arrastão", diz \n Helena...
# 1  Democracia Política e novo Reformismo: Pablo O...
# 2  @AndreJanonesAdv @LulaOficial Vai lá André Jan...
# 3  observação importante: Nelson se elegeu pelo A...
# 4  @AndreJanonesAdv O mais legal é que o novo Jea...

# %%
dataframe_tweets_andre_janones['Cadidato'] = 'André'

# %%
dataframe_tweets_andre_janones.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 14:58:17+00:00  1553394554245611521
# 1 2022-07-30 14:52:18+00:00  1553393051447476225
# 2 2022-07-30 14:51:22+00:00  1553392814909784064
# 3 2022-07-30 14:49:22+00:00  1553392312616632321
# 4 2022-07-30 14:48:01+00:00  1553391972160782337
#
#                                                Tweet Cadidato
# 0  "Lula está fazendo um arrastão", diz \n Helena...    André
# 1  Democracia Política e novo Reformismo: Pablo O...    André
# 2  @AndreJanonesAdv @LulaOficial Vai lá André Jan...    André
# 3  observação importante: Nelson se elegeu pelo A...    André
# 4  @AndreJanonesAdv O mais legal é que o novo Jea...    André

# %% [markdown]
# #Leonardo Péricles

# %%
lista_de_twitts_leonardo_pericles = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper ( ['leonardo péricles'] ).get_items ()):
  if i > maximo_de_tweets:
    break
  lista_de_twitts_leonardo_pericles.append ([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_leonardo_pericles = pd.DataFrame(lista_de_twitts_leonardo_pericles, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_leonardo_pericles.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 09:07:57+00:00  1553306390495727617
# 1 2022-07-30 02:56:13+00:00  1553212842635059200
# 2 2022-07-30 02:33:50+00:00  1553207211161227264
# 3 2022-07-30 01:12:28+00:00  1553186730655862784
# 4 2022-07-30 00:40:01+00:00  1553178565105094659
#
#                                                Tweet
# 0                                  #LeonardoPericles
# 1  #BolsonaroNaCadeia, Ciro, Simone, Bivar, Janon...
# 2                   @ThiagoResiste #LeonardoPericles
# 3  ☆☆☆●●●ATENÇÃO TODOS NEGROS E NEGRAS DO BRASIL ...
# 4  &gt;&gt;&gt;*** *** ALGUMA REDE DE  TELEVISÃO ...

# %%
dataframe_tweets_leonardo_pericles['Cadidato'] = 'Péricles'

# %%
dataframe_tweets_leonardo_pericles.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 09:07:57+00:00  1553306390495727617
# 1 2022-07-30 02:56:13+00:00  1553212842635059200
# 2 2022-07-30 02:33:50+00:00  1553207211161227264
# 3 2022-07-30 01:12:28+00:00  1553186730655862784
# 4 2022-07-30 00:40:01+00:00  1553178565105094659
#
#                                                Tweet  Cadidato
# 0                                  #LeonardoPericles  Péricles
# 1  #BolsonaroNaCadeia, Ciro, Simone, Bivar, Janon...  Péricles
# 2                   @ThiagoResiste #LeonardoPericles  Péricles
# 3  ☆☆☆●●●ATENÇÃO TODOS NEGROS E NEGRAS DO BRASIL ...  Péricles
# 4  &gt;&gt;&gt;*** *** ALGUMA REDE DE  TELEVISÃO ...  Péricles
